# %% [markdown]
# # Actividad para minimizar el impacto del sobre-ajuste.
#
# ## Etapa 1: Definición de los datos.
#
# Antes de comenzar definimos la base de datos de interés. Usaremos la base de datos IMBD que consiste en reseñas hechas a 25000 películas. La tarea que configura esta base de datos consiste en predecir si el comentario es positivo o negativo. ([Ver enlace](https://keras.io/api/datasets/imdb/))

# %% [markdown]
# Se cargan las librerías necesarias

# %%
from keras.datasets import imdb
import numpy as np
from keras import models
from keras import layers
from keras import regularizers
import matplotlib.pyplot as plt

# %% [markdown]
# Se carga la base de datos

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)

# %% [markdown]
# Se definen funciones para la visualización de la función de costo

# %%
def evaluate(model, history):
    # Se evalúa el accuracy del modelo tanto en el conjunto de entrenamiento como 
    # en el de prueba.
    _, train_accuracy = model.evaluate(x_train, y_train)
    _, test_accuracy = model.evaluate(x_test, y_test)

    print(f"Trainining accuracy: {train_accuracy:.2f}")
    print(f"Testing accuracy: {test_accuracy:.2f}")

    # Se grafica la función de costo para los conjuntos de entrenamiento y 
    # prueba.
    plt.figure(figsize=(4, 3), dpi=160)

    plt.plot(history.history["loss"], label="train")
    plt.plot(history.history["val_loss"], label="test")
    plt.legend()
    plt.show()

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# %%
# Procesamiento de los datos.
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
# Se definen los conjuntos de entrenamiento y prueba
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
# Se define la red neuronal.

model = models.Sequential([
  layers.Dense(16, activation='relu', input_shape=(10000,)),
  layers.Dense(16, activation='relu'),
  layers.Dense(1, activation='sigmoid')
  ])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=50,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 30/30 [==============================] - 3s 63ms/step - loss: 0.5160 - accuracy: 0.7977 - val_loss: 0.4085 - val_accuracy: 0.8453
# Epoch 2/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.3151 - accuracy: 0.8995 - val_loss: 0.3168 - val_accuracy: 0.8807
# Epoch 3/50
# 30/30 [==============================] - 1s 38ms/step - loss: 0.2329 - accuracy: 0.9251 - val_loss: 0.2807 - val_accuracy: 0.8888
# Epoch 4/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1827 - accuracy: 0.9421 - val_loss: 0.2965 - val_accuracy: 0.8796
# Epoch 5/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1502 - accuracy: 0.9513 - val_loss: 0.2896 - val_accuracy: 0.8850
# Epoch 6/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1230 - accuracy: 0.9627 - val_loss: 0.2889 - val_accuracy: 0.8860
# Epoch 7/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.1037 - accuracy: 0.9696 - val_loss: 0.3272 - val_accuracy: 0.8791
# Epoch 8/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0847 - accuracy: 0.9769 - val_loss: 0.3220 - val_accuracy: 0.8833
# Epoch 9/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0704 - accuracy: 0.9811 - val_loss: 0.3428 - val_accuracy: 0.8767
# Epoch 10/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0577 - accuracy: 0.9849 - val_loss: 0.3703 - val_accuracy: 0.8795
# Epoch 11/50
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0448 - accuracy: 0.9901 - val_loss: 0.4187 - val_accuracy: 0.8689
# Epoch 12/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0361 - accuracy: 0.9920 - val_loss: 0.4568 - val_accuracy: 0.8652
# Epoch 13/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0313 - accuracy: 0.9927 - val_loss: 0.4493 - val_accuracy: 0.8736
# Epoch 14/50
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0199 - accuracy: 0.9973 - val_loss: 0.4827 - val_accuracy: 0.8699
# Epoch 15/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0187 - accuracy: 0.9975 - val_loss: 0.5126 - val_accuracy: 0.8701
# Epoch 16/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 0.5532 - val_accuracy: 0.8701
# Epoch 17/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0090 - accuracy: 0.9996 - val_loss: 0.5877 - val_accuracy: 0.8682
# Epoch 18/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0079 - accuracy: 0.9993 - val_loss: 0.6225 - val_accuracy: 0.8677
# Epoch 19/50
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 0.6501 - val_accuracy: 0.8676
# Epoch 20/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0035 - accuracy: 0.9999 - val_loss: 0.7002 - val_accuracy: 0.8624
# Epoch 21/50
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.7193 - val_accuracy: 0.8647
# Epoch 22/50
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.7591 - val_accuracy: 0.8646
# Epoch 23/50
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.7782 - val_accuracy: 0.8632
# Epoch 24/50
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.8024 - val_accuracy: 0.8638
# Epoch 25/50
# 30/30 [==============================] - 2s 51ms/step - loss: 9.8036e-04 - accuracy: 0.9999 - val_loss: 0.8478 - val_accuracy: 0.8648
# Epoch 26/50
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.8757 - val_accuracy: 0.8647
# Epoch 27/50
# 30/30 [==============================] - 1s 38ms/step - loss: 5.4995e-04 - accuracy: 0.9999 - val_loss: 0.8969 - val_accuracy: 0.8634
# Epoch 28/50
# 30/30 [==============================] - 1s 36ms/step - loss: 4.5135e-04 - accuracy: 1.0000 - val_loss: 0.9726 - val_accuracy: 0.8586
# Epoch 29/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.9821 - val_accuracy: 0.8626
# Epoch 30/50
# 30/30 [==============================] - 1s 37ms/step - loss: 2.2435e-04 - accuracy: 1.0000 - val_loss: 1.0017 - val_accuracy: 0.8631
# Epoch 31/50
# 30/30 [==============================] - 1s 36ms/step - loss: 1.8027e-04 - accuracy: 1.0000 - val_loss: 1.0459 - val_accuracy: 0.8623
# Epoch 32/50
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 1.0922 - val_accuracy: 0.8621
# Epoch 33/50
# 30/30 [==============================] - 1s 38ms/step - loss: 1.1185e-04 - accuracy: 1.0000 - val_loss: 1.1050 - val_accuracy: 0.8609
# Epoch 34/50
# 30/30 [==============================] - 1s 37ms/step - loss: 8.5449e-05 - accuracy: 1.0000 - val_loss: 1.1307 - val_accuracy: 0.8598
# Epoch 35/50
# 30/30 [==============================] - 1s 39ms/step - loss: 6.7273e-05 - accuracy: 1.0000 - val_loss: 1.2058 - val_accuracy: 0.8563
# Epoch 36/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 1.2280 - val_accuracy: 0.8598
# Epoch 37/50
# 30/30 [==============================] - 1s 49ms/step - loss: 3.2588e-05 - accuracy: 1.0000 - val_loss: 1.2398 - val_accuracy: 0.8591
# Epoch 38/50
# 30/30 [==============================] - 1s 36ms/step - loss: 2.8091e-05 - accuracy: 1.0000 - val_loss: 1.2552 - val_accuracy: 0.8598
# Epoch 39/50
# 30/30 [==============================] - 1s 37ms/step - loss: 2.4101e-05 - accuracy: 1.0000 - val_loss: 1.2821 - val_accuracy: 0.8598
# Epoch 40/50
# 30/30 [==============================] - 1s 37ms/step - loss: 1.8236e-05 - accuracy: 1.0000 - val_loss: 1.3391 - val_accuracy: 0.8584
# Epoch 41/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 1.3967 - val_accuracy: 0.8589
# Epoch 42/50
# 30/30 [==============================] - 1s 37ms/step - loss: 7.9390e-06 - accuracy: 1.0000 - val_loss: 1.4053 - val_accuracy: 0.8581
# Epoch 43/50
# 30/30 [==============================] - 1s 36ms/step - loss: 7.2087e-06 - accuracy: 1.0000 - val_loss: 1.4155 - val_accuracy: 0.8578
# Epoch 44/50
# 30/30 [==============================] - 1s 36ms/step - loss: 6.5220e-06 - accuracy: 1.0000 - val_loss: 1.4332 - val_accuracy: 0.8577
# Epoch 45/50
# 30/30 [==============================] - 1s 36ms/step - loss: 5.4510e-06 - accuracy: 1.0000 - val_loss: 1.4675 - val_accuracy: 0.8576
# Epoch 46/50
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 1.5373 - val_accuracy: 0.8581
# Epoch 47/50
# 30/30 [==============================] - 2s 62ms/step - loss: 5.1721e-06 - accuracy: 1.0000 - val_loss: 1.5209 - val_accuracy: 0.8579
# Epoch 48/50
# 30/30 [==============================] - 1s 46ms/step - loss: 3.7159e-06 - accuracy: 1.0000 - val_loss: 1.5260 - val_accuracy: 0.8572
# Epoch 49/50
# 30/30 [==============================] - 1s 38ms/step - loss: 2.9574e-06 - accuracy: 1.0000 - val_loss: 1.5355 - val_accuracy: 0.8572
# Epoch 50/50
# 30/30 [==============================] - 1s 37ms/step - loss: 2.4305e-06 - accuracy: 1.0000 - val_loss: 1.5611 - val_accuracy: 0.8579

# %%
evaluate(model, history)
# Out:
# 782/782 [==============================] - 2s 3ms/step - loss: 0.6245 - accuracy: 0.9432
# 782/782 [==============================] - 2s 2ms/step - loss: 1.6960 - accuracy: 0.8433
# Trainining accuracy: 0.94
# Testing accuracy: 0.84

# %% [markdown]
# El modelo que entrenemos presenta sobre ajuste. Así, debemos construir una bitácora donde reportemos los siguientes análisis.
#
# Indicar los elementos que tuvimos en cuenta para verificar que el modelo inicial se encuentra en sobreajuste.
# Modificar el modelo inicial con el fin de minimizar el impacto del sobreajuste y reportar los resultados obtenidos en términos de la función de pérdida. En particular debemos experimentar las siguientes variaciones:
# * Modelo inicial sin ninguna * modificación.
# * Modelo inicial añadiendo * regularización L2.
# * Modelo inicial añadiendo dropout.
# * Modelo que combine ambas estrategias de regularización.
